# %% [markdown]
# Primero tenemos que definir el dataset en este caso se funcionaron los 3 propuestos en uno solo a continuación se entrenara el modelo de detección con yoloV8 en su modelo mas ligero para aminorar el tiempo de entreanmiento

# %%
# !/bin/.extreme_cooling start # Configurar mis ventiladores de mi laptop al 100%
# !cd ../dataset && yolo task=detect mode=train epochs=45 data=mergeData/data.yaml model=yolov8n.pt imgsz=640 batch=43
# !/bin/.extreme_cooling stop # Configurar mis ventiladores de mi laptop al 30%
# Out:
# extreme cooling started
# old value 00
# new value 40
# New https://pypi.org/project/ultralytics/8.0.221 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.9 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1060, 6072MiB)
# ...

# %% [markdown]
# Una vez terminado el entrenamiento se realizaran algunas pruebas de deteccion con la camara

# %%
# Importamos las librerias
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import time

# Leer nuestro modelo
model = YOLO("../models/modelV1.pt")

# Realizar VideoCaptura
cap = cv2.VideoCapture(0)

# Configurar la frecuencia de captura (cada 3 segundos)
intervalo_captura = 5  # en segundos
ultimo_tiempo_captura = time.time()

# Bucle
while True:
    # Leer nuestros fotogramas
    ret, frame = cap.read()

    # Leemos resultados
    resultados = model.predict(frame, imgsz=640, conf=0.6)

    # Mostramos resultados
    anotaciones = resultados[0].plot()

    # Mostramos nuestros fotogramas
    cv2.imshow("DETECCION", anotaciones)

    # Capturar imagen cada intervalo_captura segundos
    tiempo_actual = time.time()
    if tiempo_actual - ultimo_tiempo_captura >= intervalo_captura:
        # Guardar la imagen capturada
        nombre_archivo = f"imagen_{int(tiempo_actual)}.jpg"
        cv2.imwrite(nombre_archivo, frame)
        print(f"Imagen guardada como {nombre_archivo}")

        # Actualizar el tiempo de la última captura
        ultimo_tiempo_captura = tiempo_actual

        # Procesar la imagen guardada por el modelo
        imagen_guardada = cv2.imread(nombre_archivo)
        resultados_guardados = model.predict(imagen_guardada, imgsz=640, conf=0.7)

        # Mostrar resultados de la imagen guardada
        anotaciones_guardadas = resultados_guardados[0].plot()
        plt.imshow(cv2.cvtColor(anotaciones_guardadas, cv2.COLOR_BGR2RGB))
        plt.title("Resultados de la imagen guardada")
        plt.show()

    # Cerrar nuestro programa
    if cv2.waitKey(1) == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.0ms
# Speed: 3.2ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# Speed: 3.2ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 5.9ms
# ...

# %%
# Importamos las librerias
from ultralytics import YOLO
import cv2

# Leer nuestro modelo
model = YOLO("../models/modelV2.pt")

# Realizar VideoCaptura
cap = cv2.VideoCapture(0)

# Bucle
while True:
    # Leer nuestros fotogramas
    ret, frame = cap.read()

    # Leemos resultados
    resultados = model.predict(frame, imgsz = 640, conf = 0.7)

    # Mostramos resultados
    anotaciones = resultados[0].plot()

    # Mostramos nuestros fotogramas
    cv2.imshow("DETECCION", anotaciones)

    # Cerrar nuestro programa
    if cv2.waitKey(1) == 27:
        break

        

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 rock, 9.1ms
# Speed: 1.1ms preprocess, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 rock, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.3ms
# Speed: 1.8ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.5ms
# ...

# %% [markdown]
# Con mas epocas

# %%
# !/bin/.extreme_cooling start # Configurar mis ventiladores de mi laptop al 100%
# !cd ../dataset && yolo task=detect mode=train epochs=130 data=mergeData/data.yaml model=yolov8n.pt imgsz=640 batch=42
# !/bin/.extreme_cooling stop # Configurar mis ventiladores de mi laptop al 30%
# Out:
# extreme cooling started
# old value 00
# new value 40
# New https://pypi.org/project/ultralytics/8.0.221 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.217 🚀 Python-3.10.9 torch-2.1.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1060, 6072MiB)
# ...
